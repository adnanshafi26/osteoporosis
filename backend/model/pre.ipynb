# %%
import pandas 
data=pandas.read_csv('C:\\Users\\Afreen\\osteoporosis-ai-detection\\backend\\osteoporosis_dataset_10000_final.csv')
data
# Out:
#          id  age  gender   bmi  bone_density  bone_type  calcium  vitamin_d  \
# 0         1   84       1  22.2         0.867          0   1031.9      609.8
# 1         2   61       0  20.7         0.750          1   1033.3      717.2
# 2         3   65       0  23.5         0.984          1   1041.7      618.1
# 3         4   79       1  23.2         0.793          3   1093.5      699.6
# 4         5   66       1  21.9         0.893          0   1001.8      730.9
# ...     ...  ...     ...   ...           ...        ...      ...        ...
# 9995   9996   42       0  24.9         0.891          1   1092.6      635.5
# 9996   9997   62       0  22.4         0.944          1   1106.0      717.2
# 9997   9998   58       0  20.5         0.943          2   1095.6      700.6
# 9998   9999   82       1  22.5         1.029          2   1090.3      713.3
# 9999  10000   75       1  19.0         0.870          3   1023.0      600.0
#
#       label
# 0         0
# 1         0
# 2         0
# ...

# %%
data.isna().sum()
# Out:
# id              0
# age             0
# gender          0
# bmi             0
# bone_density    0
# bone_type       0
# calcium         0
# vitamin_d       0
# label           0
# dtype: int64
